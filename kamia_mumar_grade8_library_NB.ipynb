# %% [markdown]
# <a href="https://colab.research.google.com/github/MarvinJacobPMumar/kamia-mumar-grade8-library-Repo/blob/main/kamia_mumar_grade8_library_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
link = "https://raw.githubusercontent.com/MarvinJacobPMumar/kamia-mumar-grade8-library-Repo/refs/heads/main/books.json"
response = requests.get(link)
books = response.json()
print(books)
# Out:
# {'books': [{'id': 2001, 'title': 'Introduction to Python', 'author': 'Juan Dela Cruz', 'details': {'copies': 5, 'available': 3}}, {'id': 2002, 'title': 'Data Structures Basics', 'author': 'Maria Santos', 'details': {'copies': 4, 'available': 2}}, {'id': 2003, 'title': 'Web Development Essentials', 'author': 'Carlos Reyes', 'details': {'copies': 6, 'available': 6}}]}

# %%
import firebase_admin
from firebase_admin import credentials, db

credential = credentials.Certificate("/content/firebase_key.json")
firebase_admin.initialize_app(credential, { "databaseURL" : "https://kamia-mumar-grade8-library-db-default-rtdb.asia-southeast1.firebasedatabase.app/"})
print("Succesfully connected to Firebase.")
# Out:
# Succesfully connected to Firebase.

# %%
import json

data = books
print("Loaded JSON file")
reference = db.reference("books")
for book in data["books"]:
  reference.child(str(book["id"])).set(book)
print("Data succesfully uploaded.")
# Out:
# Loaded JSON file
# Data succesfully uploaded.

# %%
books_data = reference.get()
print(f"Data: {books_data} \n")

print("Books in library:", end = " ")
for i, book in enumerate(books_data.values()):
  if i + 1 == len(books_data.values()):
    print(f"and {book["title"]} \n")
  else:
    print(book["title"], end = ", ")


booksinlibrary = 0
print("Availability for each book:")
for book in books_data.values():
  details = book["details"]
  print(f"  {book["title"]}:")
  print(f"    {details["available"]}/{details["copies"]} copies")
  booksinlibrary += details["available"]

print(f"\nTotal available books in the library: {booksinlibrary}")
# Out:
# Data(disorganized): {'2001': {'author': 'Juan Dela Cruz', 'details': {'available': 3, 'copies': 5}, 'id': 2001, 'title': 'Introduction to Python'}, '2002': {'author': 'Maria Santos', 'details': {'available': 2, 'copies': 4}, 'id': 2002, 'title': 'Data Structures Basics'}, '2003': {'author': 'Carlos Reyes', 'details': {'available': 6, 'copies': 6}, 'id': 2003, 'title': 'Web Development Essentials'}}
#
# Books in library: Introduction to Python, Data Structures Basics, and Web Development Essentials
#
# Availability for each book:
#   Introduction to Python:
#     3/5 copies
#   Data Structures Basics:
#     2/4 copies
#   Web Development Essentials:
#     6/6 copies
#
# Total available books in the library: 11
